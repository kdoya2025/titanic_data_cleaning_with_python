# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\USER\OneDrive\Documents\pandas tutoriel\personal_data_cleaning.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                            Full_name     Sex  Age  SibSp  \
# 0                             Mr. Owen Harris Braund    male   22      1
# 1   Mrs. John Bradley (Florence Briggs Thayer) Cu...  female   38      1
# 2                              Miss. Laina Heikkinen  female   26      0
# 3        Mrs. Jacques Heath (Lily May Peel) Futrelle  female   35      1
# 4                            Mr. William Henry Allen    male   35      0
#
#    Parch         Ticket     Fare Embarked
# 0      0        A521171   7.2500        S
# 1      0        PC17599  71.2833        C
# 2      0  STONO23101282   7.9250        S
# 3      0         113803  53.1000        S
# 4      0         373450   8.0500        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                             Full_name  \
# 700          886         0       3   Mrs. William (Margaret Norton) Rice
# 701          887         0       2                  Rev. Juozas Montvila
# 702          888         1       1           Miss. Margaret Edith Graham
# 703          890         1       1                  Mr. Karl Howell Behr
# 704          891         0       3                    Mr. Patrick Dooley
#
#         Sex  Age  SibSp  Parch  Ticket    Fare Embarked
# 700  female   39      0      5  382652  29.125        Q
# 701    male   27      0      0  211536  13.000        S
# 702  female   19      0      0  112053  30.000        S
# 703    male   26      0      0  111369  30.000        C
# 704    male   32      0      0  370376   7.750        Q

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 705 entries, 0 to 704
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  705 non-null    int64
#  1   Survived     705 non-null    int64
#  2   Pclass       705 non-null    int64
#  3   Full_name    705 non-null    object
#  4   Sex          705 non-null    object
#  5   Age          705 non-null    int64
#  6   SibSp        705 non-null    int64
#  7   Parch        705 non-null    int64
#  8   Ticket       705 non-null    object
#  9   Fare         705 non-null    float64
#  10  Embarked     705 non-null    object
# dtypes: float64(1), int64(6), object(4)
# memory usage: 60.7+ KB

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Full_name       object
# Sex             object
# Age              int64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked        object
# dtype: object

# %%
df.nunique()
# Out:
# PassengerId    705
# Survived         2
# Pclass           3
# Full_name      705
# Sex              2
# Age             70
# SibSp            6
# Parch            7
# Ticket         540
# Fare           218
# Embarked         3
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   705.000000  705.000000  705.000000  705.000000  705.000000
# mean    447.523404    0.398582    2.239716   29.916312    0.509220
# std     258.419024    0.489954    0.838092   14.269328    0.930993
# min       1.000000    0.000000    1.000000    1.000000    0.000000
# 25%     222.000000    0.000000    1.000000   21.000000    0.000000
# 50%     443.000000    0.000000    2.000000   28.000000    0.000000
# 75%     676.000000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    5.000000
#
#             Parch        Fare
# count  705.000000  705.000000
# mean     0.424113   34.540496
# std      0.852961   52.993636
# min      0.000000    0.000000
# 25%      0.000000    8.050000
# 50%      0.000000   15.500000
# 75%      1.000000   33.000000
# max      6.000000  512.329200

# %%
df.corr(numeric_only= True)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000  0.024849 -0.039460  0.043414 -0.087133 -0.011306
# Survived        0.024849  1.000000 -0.361007 -0.059425 -0.022081  0.084376
# Pclass         -0.039460 -0.361007  1.000000 -0.374130  0.063611  0.026477
# Age             0.043414 -0.059425 -0.374130  1.000000 -0.304196 -0.172489
# SibSp          -0.087133 -0.022081  0.063611 -0.304196  1.000000  0.384124
# Parch          -0.011306  0.084376  0.026477 -0.172489  0.384124  1.000000
# Fare            0.013841  0.268495 -0.551289  0.096796  0.140764  0.204917
#
#                  Fare
# PassengerId  0.013841
# Survived     0.268495
# Pclass      -0.551289
# Age          0.096796
# SibSp        0.140764
# Parch        0.204917
# Fare         1.000000

# %%
sns.heatmap(df.corr(numeric_only= True), annot= True)
plt.rcParams['figure.figsize']=(20,7)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Full_name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
df.groupby('Embarked').mean(numeric_only= True)
# Out:
#           PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Embarked
# C          448.921260  0.598425  1.716535  31.503937  0.401575  0.401575
# Q          414.035714  0.285714  2.785714  28.035714  0.750000  0.392857
# S          448.905455  0.358182  2.332727  29.645455  0.521818  0.430909
#
#                Fare
# Embarked
# C         69.539735
# Q         18.265775
# S         27.287385
